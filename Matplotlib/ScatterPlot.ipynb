# %%
# plt.scatter(x,y, color="color_name",marker="marker_style", label="label_name")
import matplotlib.pyplot as plt
hours_studies = [1,2,3,4,5,6,7,8]
exam_scores = [50,55,60,65,70,75,80,85]

plt.scatter(hours_studies,exam_scores,color="red" , lavel="hours of studies by scores" , marker=">")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 6
#       3 hours_studies = [1,2,3,4,5,6,7,8]
#       4 exam_scores = [50,55,60,65,70,75,80,85]
# ----> 6 plt.scatter(hours_studies,exam_scores,color="red" , lavel="hours of studies by scores" , marker=">")
#       7 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
# plt.scatter(x,y, color="color_name",marker="marker_style", label="label_name")
import matplotlib.pyplot as plt
hours_studies = [1,2,3,4,5,6,7,8]
exam_scores = [50,55,60,65,70,75,80,85]

plt.scatter(hours_studies,exam_scores,color="red" , label="hours of studies by scores" , marker=">")
plt.legend()
plt.show()

# %%
# plt.scatter(x,y, color="color_name",marker="marker_style", label="label_name")
import matplotlib.pyplot as plt
hours_studies = [1,2,3,4,5,6,7,8]
exam_scores = [50,55,60,65,70,75,80,85]

plt.scatter(hours_studies,exam_scores,color="red" , label="hours of studies by scores" , marker="o")
plt.legend()
plt.show()

# %%
# plt.scatter(x,y, color="color_name",marker="marker_style", label="label_name")
import matplotlib.pyplot as plt
hours_studies = [1,2,3,4,5,6,7,8]
exam_scores = [50,55,60,65,70,75,80,85]

plt.scatter(hours_studies,exam_scores,color="red" , label="hours of studies by scores" , marker=">")
plt.xlabel("hours of studies")
plt.ylabel("scores of exam")
plt.title("Relationship between studies hours and exam scores")
plt.legend()
plt.grid(True)
plt.show()

# %%
# plt.scatter(x,y, color="color_name",marker="marker_style", label="label_name")
import matplotlib.pyplot as plt
hours_studies = [1,2,3,4,5,6,7,8]
exam_scores = [50,55,60,65,70,75,80,85]

plt.scatter(hours_studies,exam_scores,color="red" , label="hours of studies by scores" , marker=">")
plt.xlabel("hours of studies")
plt.ylabel("scores of exam")
plt.title("Relationship between studies hours and exam scores")
# plt.legend()
plt.grid(True)
plt.show()

# %%
# plt.scatter(x,y, color="color_name",marker="marker_style", label="label_name")
import matplotlib.pyplot as plt
hours_studies = [1,2,3,4,5,6,7,8]
exam_scores = [50,55,60,65,70,75,80,85]

plt.scatter(hours_studies,exam_scores,color="red" , label="hours of studies by scores" , marker=">")
plt.xlabel("hours of studies")
plt.ylabel("scores of exam")
plt.title("Relationship between studies hours and exam scores")
plt.legend()
plt.grid(True)
plt.show()

# %%
# plt.scatter(x,y, color="color_name",marker="marker_style", label="label_name")
import matplotlib.pyplot as plt
hours_studies = [1,2,3,4,5,6,7,8]
exam_scores = [50,55,60,65,70,75,80,85]

plt.scatter(hours_studies,exam_scores,color="red" , label="Student Data" , marker=">")
plt.xlabel("hours of studies")
plt.ylabel("scores of exam")
plt.title("Relationship between studies hours and exam scores")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter([1,2,3,4],[20,25,30,35],color="orange",marker="^",label="Section A")
plt.scatter([1,2,3,4],[10,15,20,25],color="blue", marker="*",label="Section B")
plt.xlabel("studes hours")
plt.ylabel("exam scores")
plt.title("Relationship between section A and section B students data")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter([1,2,3,4],[20,25,30,35],color="orange",marker="^",label="Section A")
plt.scatter([1,2,3,4],[10,15,20,25],color="blue", marker="*",label="Section B")
plt.xlabel("studes hours")
plt.ylabel("exam scores")
plt.title("Relationship between section A and section B students data")
plt.legend()
plt.grid(True)
plt.show()
